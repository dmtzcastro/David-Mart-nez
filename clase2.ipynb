# %% [markdown]
# # Páginas para programar python

# %% [markdown]
# 1. www.mybinder.org
# 2. www.kaggle.com
# 3. www.jupyter.org/try
# 4. `github jobish` https://mybinder.org/v2/gh/jobish03/jobish03-Visualizacion_de_datos_para_la_toma_de_decisiones/main?filepath=welcome_binder.ipynb
#
# Los paquetes hay que incluir en el archivo `requirements.txt`

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.21.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
open numpy as np
# Out:
#   File "/tmp/ipykernel_97/1468780802.py", line 1
#     open numpy as np
#              ^
# SyntaxError: invalid syntax

# %%
type(3)

# %%
type(3.0)

# %%
type(-3)

# %%
type (3/5)

# %%
x ='nombre1'
x

# %%
print('math.pi')

# %%
import math

# %%
## lista

# %%
una_lista = [1, 3/5, 'nombre', math.pi, True, 5<=3, 1==3, 3==3, None]

# %%
str_list = ['zero', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
str_list.sort()
str_list

# %%
numbers = [11, 2, 3, 4, 5, 61]
numbers
# Out:
# [11, 2, 3, 4, 5, 61]

# %%
numbers[0]
# Out:
# 11

# %%
numbers[5]
# Out:
# 61

# %%
numbers[-1]
# Out:
# 61

# %%
numbers[:3]
# Out:
# [11, 2, 3]

# %%
numbers [1:3]
# Out:
# [2, 3]

# %%
numbers [2:5]
# Out:
# [3, 4, 5]

# %%
sum(numbers)
# Out:
# 86

# %%
x =sum(numbers)
x
# Out:
# 86

# %%
len(numbers)
# Out:
# 6

# %%
y = len(numbers)
y
# Out:
# 6

# %%
promedio = x/y
promedio
# Out:
# 14.333333333333334

# %% [markdown]
# # una for loop

# %%
numbers
# Out:
# [11, 2, 3, 4, 5, 61]

# %%
for i in una_lista:
    print(i)
# Out:
# 1
# 0.6
# nombre
# 3.141592653589793
# True
# False
# False
# True
# None

# %%
for i in una_lista:
    print(i, '\t\t',type(i))
# Out:
# 1 		 <class 'int'>
# 0.6 		 <class 'float'>
# nombre 		 <class 'str'>
# 3.141592653589793 		 <class 'float'>
# True 		 <class 'bool'>
# False 		 <class 'bool'>
# False 		 <class 'bool'>
# True 		 <class 'bool'>
# None 		 <class 'NoneType'>

# %%
x = 6
y = 1
if x < y:
    print(' x es menor que y ')
else:
    print( ' x es mayor que y' )
# Out:
#  x es mayor que y

# %%
x = 6
y = 11
if x < y:
    print( ' {} es menor que {} '.format(x,y))
else:
    print( ' {} es mayor que {} '.format(x,y))
# Out:
#  6 es menor que 11
